# %% [markdown]
# lab1:

# %% [markdown]
# pandas

# %%
import pandas as pd# type: ignore

data={
    "tên":["anh", "mĩ", "huy" ,"duy"],
    "tuổi":[20, 21, 19, 22],
    "điểm":[50,55,60,65]
}
df = pd.DataFrame(data)
print(df)
# Out:
#    tên  tuổi  điểm
# 0  anh    20    50
# 1   mĩ    21    55
# 2  huy    19    60
# 3  duy    22    65

# %%
print(df['tuổi'])
print(df.iloc[0])
print(df[df["điểm"]>55])
# Out:
# 0    20
# 1    21
# 2    19
# 3    22
# Name: tuổi, dtype: int64
# tên     anh
# tuổi     20
# điểm     50
# Name: 0, dtype: object
#    tên  tuổi  điểm
# 2  huy    19    60
# 3  duy    22    65

# %%
import matplotlib.pyplot as plt

# %%
#vễ biểu đồ đường
x=[1,2,34,5,6]
y=[3,6,3,2,18]
plt.plot(x,y, label='biểu đồ đường', color='red', marker='o')
plt.title("biểu đồ đường")
plt.xlabel("x")
plt.ylabel("y")
plt.show()

# %%
ten=
diem=
plt.plot(ten,diem label='biểu đồ cot', color='red')
plt.title("biểu đồ cot")
plt.xlabel("ten")
plt.ylabel("diem")
plt.show()

# %%
x=
y=
